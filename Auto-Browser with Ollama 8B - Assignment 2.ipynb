# %%
# !apt-get update -qq
# !apt-get install -y zstd
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 96 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 0s (9,131 kB/s)
# Selecting previously unselected package zstd.
# (Reading database ... 122403 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# !find / -name ollama 2>/dev/null | head -20
# Out:
# /usr/local/lib/ollama
# /usr/local/bin/ollama
# /usr/share/ollama

# %%
# !/usr/local/bin/ollama --version
# Out:
# Warning: could not connect to a running Ollama instance
# Warning: client version is 0.30.10

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !nvidia-smi
# Out:
# Mon Jun 22 22:18:51 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !/usr/local/bin/ollama serve
# Out:
# Couldn't find '/root/.ollama/id_ed25519'. Generating new private key.
# Your new public key is:
#
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIE8QwAl7/iNo0I3/opIUlQ4F02bPUHg8+P5qmCyBZzrk
#
# time=2026-06-22T22:11:30.887Z level=INFO source=routes.go:1919 msg="server config" env="map[CUDA_VISIBLE_DEVICES: GGML_VK_VISIBLE_DEVICES: GPU_DEVICE_ORDINAL: HIP_VISIBLE_DEVICES: HSA_OVERRIDE_GFX_VERSION: HTTPS_PROXY: HTTP_PROXY: LLAMA_ARG_FIT: LLAMA_ARG_FIT_TARGET: NO_PROXY: OLLAMA_CONTEXT_LENGTH:0 OLLAMA_DEBUG:INFO OLLAMA_DEBUG_LOG_REQUESTS:false OLLAMA_EDITOR: OLLAMA_FLASH_ATTENTION:false OLLAMA_GO_TEMPLATE:true OLLAMA_GPU_OVERHEAD:0 OLLAMA_HOST:http://127.0.0.1:11434 OLLAMA_IGPU_ENABLE: OLLAMA_KEEP_ALIVE:5m0s OLLAMA_KV_CACHE_TYPE: OLLAMA_LLM_LIBRARY: OLLAMA_LOAD_TIMEOUT:5m0s OLLAMA_MAX_LOADED_MODELS:0 OLLAMA_MAX_QUEUE:512 OLLAMA_MAX_TRANSFER_STREAMS:4 OLLAMA_MODELS:/root/.ollama/models OLLAMA_NOHISTORY:false OLLAMA_NOPRUNE:false OLLAMA_NO_CLOUD:false OLLAMA_NUM_PARALLEL:1 OLLAMA_ORIGINS:[http://localhost https://localhost http://localhost:* https://localhost:* http://127.0.0.1 https://127.0.0.1 http://127.0.0.1:* https://127.0.0.1:* http://0.0.0.0 https://0.0.0.0 http://0.0.0.0:* https://0.0.0.0:* app://* file://* tauri://* vscode-webview://* vscode-file://*] OLLAMA_REMOTES:[ollama.com] OLLAMA_SCHED_SPREAD:false OLLAMA_VULKAN:true ROCR_VISIBLE_DEVICES: http_proxy: https_proxy: no_proxy:]"
# time=2026-06-22T22:11:30.887Z level=INFO source=routes.go:1921 msg="Ollama cloud disabled: false"
# time=2026-06-22T22:11:30.887Z level=INFO source=images.go:864 msg="total blobs: 0"
# time=2026-06-22T22:11:30.888Z level=INFO source=images.go:871 msg="total unused blobs removed: 0"
# time=2026-06-22T22:11:30.888Z level=INFO source=routes.go:1981 msg="Listening on 127.0.0.1:11434 (version 0.30.10)"
# time=2026-06-22T22:11:30.889Z level=INFO source=model_list_cache.go:111 msg="model list cache hydration complete" models=0 failures=0 elapsed=733.511µs
# time=2026-06-22T22:11:30.890Z level=INFO source=runner.go:60 msg="discovering available GPUs..."
# time=2026-06-22T22:11:31.066Z level=INFO source=model_recommendations.go:177 msg="model recommendations cache sleep scheduled" wait=4h1m33.017045818s consecutive_failures=0
# time=2026-06-22T22:11:34.039Z level=INFO source=types.go:32 msg="inference compute" id=0 filter_id=0 library=CUDA compute=7.5 name=CUDA0 description="Tesla T4" libdirs=ollama,cuda_v13 driver=13.0 pci_id=0000:00:04.0 type=discrete total="14.6 GiB" available="14.5 GiB"
# time=2026-06-22T22:11:34.039Z level=INFO source=routes.go:2031 msg="vram-based default context" total_vram="14.6 GiB" default_num_ctx=4096

# %%
# !/usr/local/bin/ollama serve > ollama.log 2>&1 &

# %%
# !curl http://127.0.0.1:11434/api/tags
# Out:
# {"models":[]}

# %%
# !/usr/local/bin/ollama pull llama3:8b

# %%
# !/usr/local/bin/ollama run llama3:8b "What is AI?"
# Out:
# AI stands for Artificial Intelligence, which refers to the development of c
# computer systems that can perform tasks that typically require human intell
# intelligence, such as:
#
# 1. **Learning**: AI systems can learn from data and improve their performan
# performance over time.
# 2. **Reasoning**: AI systems can draw conclusions based on given informatio
# information.
# 3. **Problem-solving**: AI systems can identify problems and find solutions
# solutions.
# 4. **Perception**: AI systems can interpret and understand data from sensor
# sensors, such as images, speech, or text.
#
# There are many types of AI, including:
#
# 1. **Narrow or Weak AI**: Designed to perform a specific task, such as faci
# facial recognition or language translation.
# 2. **General or Strong AI**: A hypothetical AI that equals or surpasses hum
# human intelligence in all domains.
# 3. **Superintelligence**: An AI system that is significantly more intellige
# intelligent than the best human minds.
#
# AI uses various techniques, including:
#
# 1. **Machine Learning**: Training algorithms to make predictions based on d
# data.
# 2. **Deep Learning**: A type of machine learning using neural networks insp
# inspired by the human brain.
# 3. **Rule-based Systems**: Using pre-defined rules to generate outputs.
# 4. **Natural Language Processing (NLP)**: Enabling computers to understand,
# understand, generate, and process human language.
#
# AI applications are diverse and include:
#
# 1. **Virtual Assistants**: AI-powered assistants like Siri, Alexa, or Googl
# Google Assistant.
# 2. **Robotics**: AI-controlled robots that can perform tasks autonomously.
# 3. **Healthcare**: AI-assisted diagnosis, treatment planning, and patient m
# monitoring.
# 4. **Finance**: AI-driven trading, risk analysis, and portfolio management.
# management.
# 5. **Customer Service**: AI-powered chatbots for customer suppor
# support.
#
# As AI continues to evolve, it has the potential to transform various aspect
# aspects of our lives, from education and employment to healthcare and enter
# entertainment.
