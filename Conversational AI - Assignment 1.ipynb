# %%
# !pip install faster-whisper
# !pip install kokoro
# !pip install pipecat-ai
# !pip install openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.4/35.4 MB 39.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.5/39.5 MB 13.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 31.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 82.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 87.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 122.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 96.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 124.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.0/238.0 kB 25.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: soxr
# ...

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
import torch

print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA: True
# GPU: Tesla T4

# %%
# !nvidia-smi
# Out:
# Mon Jun 22 14:40:14 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8             11W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install faster-whisper
# !pip install kokoro
# !pip install pipecat-ai
# !pip install openai
# !pip install soundfile
# !pip install ffmpeg-python

# %%
from faster_whisper import WhisperModel

model = WhisperModel(
    "small",
    device="cuda",
    compute_type="float16"
)

print("Whisper loaded successfully")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Whisper loaded successfully

# %%
# !wget https://github.com/Jakobovski/free-spoken-digit-dataset/raw/master/recordings/0_george_0.wav
# Out:
# --2026-06-22 14:41:00--  https://github.com/Jakobovski/free-spoken-digit-dataset/raw/master/recordings/0_george_0.wav
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Jakobovski/free-spoken-digit-dataset/master/recordings/0_george_0.wav [following]
# --2026-06-22 14:41:01--  https://raw.githubusercontent.com/Jakobovski/free-spoken-digit-dataset/master/recordings/0_george_0.wav
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4812 (4.7K) [audio/wav]
# Saving to: ‘0_george_0.wav’
#
# 0_george_0.wav      100%[===================>]   4.70K  --.-KB/s    in 0s
#
# ...

# %%
from faster_whisper import WhisperModel

model = WhisperModel(
    "small",
    device="cuda",
    compute_type="float16"
)

segments, info = model.transcribe(
    "0_george_0.wav"
)

for segment in segments:
    print(segment.text)
# Out:
#  Tito.

# %%
# !pip install faster-whisper

# %%
from faster_whisper import WhisperModel

model = WhisperModel(
    "small",
    device="cuda",
    compute_type="float16"
)

print("Whisper loaded successfully")
# Out:
# Whisper loaded successfully

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
from faster_whisper import WhisperModel

model = WhisperModel(
    "small",
    device="cuda",
    compute_type="float16"
)

segments, info = model.transcribe(
    "0_george_0.wav"
)

for segment in segments:
    print(segment.text)
# Out:
#  Tito.

# %%
# !pip install kokoro soundfile

# %%
# !pip install kokoro>=0.9.4 soundfile

# %%
from kokoro import KPipeline

pipeline = KPipeline(lang_code='a')

generator = pipeline(
    "Hello, I am an AI assistant.",
    voice="af_heart"
)

for _, _, audio in generator:
    print(audio.shape)
# Out:
# WARNING: Defaulting repo_id to hexgrad/Kokoro-82M. Pass repo_id='hexgrad/Kokoro-82M' to suppress this warning.
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# torch.Size([60000])

# %%
from kokoro import KPipeline
import soundfile as sf

pipeline = KPipeline(lang_code='a')

generator = pipeline(
    "Hello, I am an AI assistant.",
    voice="af_heart"
)

for _, _, audio in generator:
    sf.write("output.wav", audio.cpu().numpy(), 24000)

print("Audio saved as output.wav")
# Out:
# WARNING: Defaulting repo_id to hexgrad/Kokoro-82M. Pass repo_id='hexgrad/Kokoro-82M' to suppress this warning.
# Audio saved as output.wav

# %%
from IPython.display import Audio

Audio("output.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google.colab import files

files.download("output.wav")

# %%
# !pip install google-generativeai

# %%
# !pip install -U google-genai

# %%
from google import genai

client = genai.Client(api_key="AIzaSyCrU4xP8wpGLTfd4cBRNzNEG6FKxbSwhMM")

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="What is artificial intelligence?"
)

print(response.text)
# Out:
# Artificial Intelligence (AI) is a broad field of computer science dedicated to **creating machines that can perform tasks typically requiring human intelligence.**
#
# In simpler terms, AI is about making computers think and act more like humans, or at least mimic certain cognitive functions.
#
# Here's a breakdown of what that means:
#
# 1.  **Simulation of Human Intelligence:** AI aims to replicate or simulate cognitive functions that we associate with the human mind, such as:
#     *   **Learning:** Acquiring information and rules for using the information.
#     *   **Reasoning:** Using rules to reach approximate or definite conclusions.
#     *   **Problem-solving:** Finding solutions to complex problems.
#     *   **Perception:** Interpreting sensory data (like vision or speech).
#     *   **Language Understanding:** Processing and generating human language.
#
# 2.  **Key Pillars/Approaches within AI:**
# ...

# %%
from google import genai

client = genai.Client(
    api_key="AIzaSyCfLpBYNbGnYrchVwAlKEb2CKTku-J0xUQ"
)

for model in client.models.list():
    print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.5-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# ...

# %%
# !pip install -U google-genai

# %%
from google import genai

client = genai.Client(
    api_key="AIzaSyCrU4xP8wpGLTfd4cBRNzNEG6FKxbSwhMM"
)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="What is artificial intelligence?"
)

print(response.text)
# Out:
# **Artificial Intelligence (AI)** is a broad field of computer science dedicated to creating machines that can perform tasks that typically require human intelligence.
#
# In essence, AI aims to replicate and automate cognitive functions that we associate with the human mind, such as:
#
# *   **Learning:** Acquiring information and rules for using the information.
# *   **Reasoning:** Using rules to reach approximate or definite conclusions.
# *   **Problem-solving:** Finding solutions to complex challenges.
# *   **Perception:** Understanding and interpreting information from the world (e.g., through images, sounds).
# *   **Language Understanding:** Processing and generating human language.
# *   **Decision-making:** Choosing the best course of action from available options.
#
# **How AI works (in simplified terms):**
#
# Modern AI primarily relies on **data** and **algorithms**.
#
# ...

# %%
from google import genai

API_KEY = "AIzaSyCfLpBYNbGnYrchVwAlKEb2CKTku-J0xUQ"

client = genai.Client(api_key=API_KEY)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Say hello"
)

print(response.text)
# Out:
# Hello!

# %%
from google import genai

client = genai.Client(api_key="AIzaSyCfLpBYNbGnYrchVwAlKEb2CKTku-J0xUQ")

for model in client.models.list():
    print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.5-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# ...

# %%
from faster_whisper import WhisperModel
from google import genai

# Whisper
whisper = WhisperModel(
    "small",
    device="cuda",
    compute_type="float16"
)

segments, info = whisper.transcribe(
    "0_george_0.wav"
)

user_text = ""

for segment in segments:
    user_text += segment.text

print("User:", user_text)

# Gemini
client = genai.Client(
    api_key="AIzaSyCfLpBYNbGnYrchVwAlKEb2CKTku-J0xUQ"
)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=user_text
)

reply = response.text

print("Gemini:", reply)
# Out:
# User:  you
# Gemini: That's a very open-ended "you"!
#
# I am a large language model, trained by Google. I don't have a personal name, physical body, or feelings like a human.
#
# I'm here to process information and generate text based on the prompts I receive.
#
# How can I help you today? Were you trying to ask me a question, or did you want to discuss something specific?

# %%
from kokoro import KPipeline
import soundfile as sf

pipeline = KPipeline(lang_code='a')

generator = pipeline(
    reply,
    voice="af_heart"
)

for _, _, audio in generator:
    sf.write(
        "reply.wav",
        audio.cpu().numpy(),
        24000
    )

print("reply.wav saved")
# Out:
# WARNING: Defaulting repo_id to hexgrad/Kokoro-82M. Pass repo_id='hexgrad/Kokoro-82M' to suppress this warning.
# reply.wav saved

# %%
from IPython.display import Audio

Audio("reply.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google import genai

client = genai.Client(
    api_key="AIzaSyCfLpBYNbGnYrchVwAlKEb2CKTku-J0xUQ"
)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Say hello in one sentence"
)

print(response.text)
# Out:
# Hello!

# %%
# !pip install pipecat-ai

# %%
import pipecat
print("Pipecat installed")
# Out:
# 15:02:22 |         __init__:28 |     INFO | ᓚᘏᗢ Pipecat 1.4.0 (Python 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]) ᓚᘏᗢ
# Pipecat installed

# %%
from pipecat.pipeline.pipeline import Pipeline

print("Pipecat pipeline initialized")
# Out:
# Pipecat pipeline initialized
